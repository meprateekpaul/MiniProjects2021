# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
df = pd.read_csv('S2.csv')
length=len(df)
df
# Out:
#                          DRUG_NAME  DRUG_ID  \
# 0                      Salinomycin  DB11544
# 1    tenofovir disoproxil fumarate  DB00300
# 2                       Tipranavir  DB00932
# 3                      Clopidogrel  DB00758
# 4                      artemisinin  DB13132
# ..                             ...      ...
# 283                     Raloxifene  DB00481
# 284                      Quercetin  DB04216
# 285                   Vildagliptin  DB04876
# 286                   Mitoxantrone  DB01204
# 287                 Mercaptopurine  DB01033
#
#                                                 SMILES
# 0    [H][C@@](C)(C(=O)[C@]([H])(CC)[C@@]1([H])O[C@@...
# 1    [H][C@@](C)(CN1C=NC2=C(N)N=CN=C12)OCP(=O)(OCOC...
# 2    [H][C@@](CC)(C1=CC(NS(=O)(=O)C2=NC=C(C=C2)C(F)...
# 3    [H][C@@](N1CCC2=C(C1)C=CS2)(C(=O)OC)C1=CC=CC=C1Cl
# 4    [H][C@@]1(C)CC[C@@]2([H])[C@@]([H])(C)C(=O)O[C...
# ..                                                 ...
# ...

# %%
df_Offside=pd.read_csv('NEW_Table_8B_Offsider_DrugwithTarget_5nearDrugs_Scored.tsv')
df_Offside
# Out:
#       drug_rxnorn_id_mainD      drugname  \
# 0                    25120   flunisolide
# 1                    61455   mizolastine
# 2                     7440    Nitrazepam
# 3                    83395    Saquinavir
# 4                     8638  prednisolone
# ...                    ...           ...
# 6587                  4637   Galantamine
# 6588                  4637   Galantamine
# 6589                  4637   Galantamine
# 6590                  4637   Galantamine
# 6591                117055   alemtuzumab
#
#                                    Drug1_Target_Name  drug_rxnorn_id_likeD  \
# 0                    Glucocorticoid receptor (NR3C1)                  8640
# 1                        Histamine H1 receptor (H1R)                 87636
# 2                  GABA(A) receptor alpha-1 (GABRA1)                 39993
# 3     Human immunodeficiency virus Protease (HIV PR)                 85762
# 4                    Glucocorticoid receptor (NR3C1)                  8640
# ...

# %%
def mapping(df,dfkey,dfvalue):
    key=dfkey
    value=dfvalue
    dictionary={}

    for i in range(len(df)):
        dictionary[key[i]]=value[i]
        
    return dictionary

# %%
s2=mapping(df,df['DRUG_NAME'].str.lower(),df['DRUG_ID'])

# %%
df_Offside['DB_DRUG_ID'] = df_Offside['drugname'].str.lower().map(s2)

# %%
df_Offside.isnull().sum()
# Out:
# drug_rxnorn_id_mainD       0
# drugname                   0
# Drug1_Target_Name          0
# drug_rxnorn_id_likeD       0
# NearDrugs                  0
# Drug2_Target_Name          0
# Matching_Score             0
# DB_DRUG_ID              5852
# dtype: int64

# %%
df_Offside.dropna(subset = ["DB_DRUG_ID"], inplace=True)

# %%
df_Offside
# Out:
#       drug_rxnorn_id_mainD        drugname  \
# 3                    83395      Saquinavir
# 9                     3616      Dobutamine
# 21                    5492  Hydrocortisone
# 32                  343047      Atazanavir
# 48                    1191         Aspirin
# ...                    ...             ...
# 6539                 10689        Tramadol
# 6541                114289       Indinavir
# 6555                114289       Indinavir
# 6570                114289       Indinavir
# 6571                114289       Indinavir
#
#                                    Drug1_Target_Name  drug_rxnorn_id_likeD  \
# 3     Human immunodeficiency virus Protease (HIV PR)                 85762
# 9                 Adrenergic receptor beta-1 (ADRB1)                  6918
# 21                   Glucocorticoid receptor (NR3C1)                  8640
# 32    Human immunodeficiency virus Protease (HIV PR)                 85762
# ...

# %%
len(df_Offside['drugname'].unique())
# Out:
# 152

# %%
df_Offside.to_csv('NEW_Table_11B_300Drug_NearDrug_Target.csv', index = False)
