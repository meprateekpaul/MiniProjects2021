# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# http://db.idrblab.net/ttd/full-data-download

# %%
df = pd.read_csv('TTD_RAW_P1-07-Drug-TargetMapping.csv')
df
# Out:
#       TargetID                                       Target_Name  DrugID  \
# 0       T56518  Hepatitis B virus Reverse transcriptase (HBV RT)  D0D5CY
# 1       T67952                 Potassium channel unspecific (KC)  D04WWG
# 2       T67054                           5-HT 1 receptor (5HT1R)  D0MS1D
# 3       T22118                        Dopamine D1 receptor (D1R)  D0S0GM
# 4       T84160                           5-HT 3 receptor (5HT3R)  D0C5DM
# ...        ...                                               ...     ...
# 43869   T76685                      Cannabinoid receptor 1 (CB1)  D0E0ZR
# 43870   T67162                        Dopamine D2 receptor (D2R)  D0OS6O
# 43871   T77913                       Histamine H1 receptor (H1R)  D08SOF
# 43872   T94033                       Coagulation factor IIa (F2)  D0JQ7Y
# 43873   T03403                  Prostaglandin G/H synthase (COX)  D0SU1G
#
#           Drug_Name           Highest_status         MOA Activity  \
# ...

# %%
df_s = pd.read_csv('NEW_Table_12_Both_offside_sider_sideeffects.csv')

# %%
df_s
# Out:
#      Unnamed: 0     DRUG_NAME  DRUG_ID  \
# 0             1   fluvoxamine  DB00176
# 1             3    Bortezomib  DB00188
# 2             4      Tramadol  DB00193
# 3             5   Oseltamivir  DB00198
# 4             6  Erythromycin  DB00199
# ..          ...           ...      ...
# 162         227   thymopentin  DB11996
# 163         239   benserazide  DB12783
# 164         240     Dinoprost  DB12789
# 165         243     Hypericin  DB13014
# 166         246   Bamifylline  DB13203
#
#                                                 SMILES  \
# 0               COCCCC\C(=N/OCCN)C1=CC=C(C=C1)C(F)(F)F
# 1    CC(C)C[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)C1=...
# 2            COC1=CC=CC(=C1)[C@@]1(O)CCCC[C@@H]1CN(C)C
# 3    CCOC(=O)C1=C[C@@H](OC(CC)CC)[C@H](NC(C)=O)[C@@...
# 4    CC[C@H]1OC(=O)[C@H](C)[C@@H](O[C@H]2C[C@@](C)(...
# ..                                                 ...
# 162  CC(C)C(NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CCCCN)N...
# ...

# %%
drugname=df["Drug_Name"]
target_name=df["Target_Name"]

# %%
drugTarget={}
for i in range(len(df)):
    key=drugname[i].lower()
    value=target_name[i]
    drugTarget[key]=value

# %%
df_s['Target_Name'] = df['Drug_Name'].str.lower().map(drugTarget)
df1= df_s[['DRUG_NAME','Target_Name']]

# %%
df_s.to_csv('Table_17_1.csv',sep="\t")

# %%
df1.isnull().sum()
# Out:
# DRUG_NAME      0
# Target_Name    0
# dtype: int64

# %%
df1.to_csv('Table_17_.csv')
