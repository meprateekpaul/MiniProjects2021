# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
df = pd.read_csv('S2.csv')
length=len(df)

# %%
df.drop_duplicates().reset_index()
df=df[['DRUG_NAME','DRUG_ID','SMILES']].drop_duplicates().reset_index()

# %%
df=df[['DRUG_NAME','DRUG_ID','SMILES']]

# %%
df_symp = pd.read_csv('NEW_Table_2C_rxnorn_id_drug_no_effect_offside.csv')
length=len(df_symp)

# %%
df_symp
# Out:
#      drug_rxnorn_id        drug_concept_name  \
# 0              4024  ergoloid mesylates, USP
# 1              7514            Norethindrone
# 2            214354              candesartan
# 3              1897        Calcium Carbonate
# 4            262100             rapacuronium
# ...             ...                      ...
# 2782         236388              LEVOMENTHOL
# 2783           8356                Piroxicam
# 2784         117055              alemtuzumab
# 2785          59768        pegademase bovine
# 2786        1306190                  BATILOL
#
#                                      SideEffectsOffSide  NoOfSideEffects
# 0     ['Anaemia', 'Aplasia pure red cell', 'Dissemin...              284
# 1     ['Iron deficiency anaemia', 'Anaemia', 'Normoc...             1793
# 2     ['Anaemia vitamin B12 deficiency', 'Iron defic...             5246
# 3     ['Anaemia vitamin B12 deficiency', 'Iron defic...             5884
# 4                    ['Cardiac arrest', 'Bronchospasm']                2
# ...                                                 ...              ...
# 2782  ['Ear infection', 'Diabetes mellitus', 'Hyperg...               14
# 2783  ['Iron deficiency anaemia', 'Anaemia', 'Anaemi...             2330
# 2784  ['Anaemia', 'Haemorrhagic anaemia', 'Anaemia o...             1978
# 2785  ['Anaemia', 'Disseminated intravascular coagul...              102
# 2786  ['Leukopenia', 'Granulocytopenia', 'Pyrexia', ...                5
#
# [2787 rows x 4 columns]

# %%
drugname=df_symp["drug_concept_name"]
side_eff=df_symp["SideEffectsOffSide"]
no_side=df_symp["NoOfSideEffects"]

# %%
drugsymp={}
for i in range(length):
    key=drugname[i].lower()
    value=no_side[i]
    drugsymp[key]=value

# %%
drugsymp
# Out:
# {'ergoloid mesylates, usp': 284,
#  'norethindrone': 1793,
#  'candesartan': 5246,
#  'calcium carbonate': 5884,
#  'rapacuronium': 2,
#  'orgotein': 113,
#  'hypromellose': 967,
#  'methyl salicylate': 624,
#  'ergotamine': 641,
#  'aldosterone': 143,
#  'norfloxacin': 1379,
#  'hydrochlorothiazide': 7491,
#  'norethandrolone': 33,
#  'iproniazid': 27,
#  'ropivacaine': 1123,
#  'thymol': 264,
#  'dextran 70': 381,
#  'norepinephrine': 1655,
#  'menthol': 1200,
#  'oxaprozin': 1293,
#  'ethosuximide': 606,
#  'dothiepin': 952,
#  'camphor, (-)-': 23,
#  'turpentine': 6,
#  'tafluprost': 359,
#  'riociguat': 504,
#  'clonixin': 31,
#  'gabapentin': 7598,
#  'prednimustine': 3,
#  'rifampin': 2844,
#  'polyvinyl alcohol': 465,
#  'insulin, pork': 102,
#  'vorinostat': 1060,
#  'deferasirox': 3145,
#  'epoetin alfa': 4287,
#  'bazedoxifene': 131,
#  'halobetasol': 440,
#  'droxidopa': 562,
#  'trifluridine': 173,
#  'panobinostat': 210,
#  'canagliflozin': 657,
#  'podophyllin': 8,
#  'yellow phenolphthalein': 19,
#  'noscapine': 53,
#  'piperazine': 35,
#  'boric acid': 91,
#  'piribedil': 525,
#  'ibutilide': 35,
#  'flopropione': 106,
#  'calcium polycarbophil': 1520,
#  'calcium glubionate': 181,
#  'racecadotril': 497,
#  'tianeptine': 870,
#  'ritonavir': 4021,
#  'epigallocatechin gallate': 1,
#  'sesame oil': 10,
#  'thyrotropin alfa': 330,
#  'tadalafil': 3226,
#  'follicle stimulating hormone': 3,
#  'meningococcal group b vaccine': 4,
#  'meloxicam': 4599,
#  'acipimox': 43,
#  'methamphetamine': 913,
#  'benzoin resin': 16,
#  'fibrinolysis inhibitor': 84,
#  'valsartan': 6669,
#  'selenium sulfide': 404,
#  'saccharomyces boulardii': 354,
#  'probucol': 252,
#  'poliovirus vaccine inactivated, type 3 (saukett)': 19,
#  'bicalutamide': 2449,
#  'astaxanthin': 74,
#  'silver sulfadiazine': 932,
#  'bosutinib': 427,
#  'trientine': 41,
#  'krill oil': 408,
#  'soybean oil': 491,
#  'sulthiame': 172,
#  'trovafloxacin': 137,
#  'sulfur hexafluoride': 31,
#  'avanafil': 28,
#  'spironolactone': 5858,
#  'carvedilol': 5697,
#  'alcuronium': 5,
#  'calcium chloride': 1087,
#  'simvastatin': 8147,
#  'hirudin': 16,
#  'sulfur': 524,
#  'strontium chloride': 60,
#  'ethambutol': 2012,
#  'ferrous asparto glycinate': 47,
#  'etofylline': 12,
#  'febuxostat': 1488,
#  'dolasetron': 1552,
#  'temozolomide': 2422,
#  'oxybutynin': 4018,
#  'dexlansoprazole': 1839,
#  'demeclocycline': 409,
#  'atropine': 2442,
#  'kanamycin': 358,
#  'troglitazone': 314,
#  'lanolin': 94,
#  'canrenone': 320,
#  'bismuth subcitrate': 17,
#  'disopyramide': 912,
#  'glucarpidase': 34,
#  'medroxyprogesterone': 3561,
#  'magnesium phosphate': 28,
#  'hepatitis b immune globulin': 54,
#  'doxercalciferol': 756,
#  'beclomethasone': 3285,
#  'apple pectin': 4,
#  'calcium phosphate': 332,
#  'probenecid': 936,
#  'aprotinin': 701,
#  'sirolimus': 2851,
#  'coal tar': 296,
#  'carbenicillin': 28,
#  'apremilast': 400,
#  'cyclobenzaprine': 4955,
#  'insulin glargine': 5618,
#  'calamine': 283,
#  'pentastarch': 18,
#  'diethylene glycol': 2,
#  'clopamide': 57,
#  'phosphoric acid': 54,
#  'choline fenofibrate': 77,
#  'reteplase': 492,
#  'parnaparin': 2,
#  'hypromellose 2208': 23,
#  'bacillus subtilis': 45,
#  'sodium stibogluconate': 38,
#  'iothalamate': 100,
#  'mebeverine': 951,
#  'raloxifene': 3298,
#  'camphor': 556,
#  'dornase alfa': 709,
#  'atomoxetine': 2534,
#  'drotrecogin alfa': 701,
#  'regorafenib': 915,
#  'cisatracurium': 996,
#  'mivacurium': 108,
#  'lenalidomide': 5677,
#  'isosorbide dinitrate': 2879,
#  'triflusal': 92,
#  'solfenacin': 16,
#  'aceprometazine': 46,
#  'phosphate ion': 10,
#  'lactobacillus reuteri': 151,
#  'prednisolone': 7608,
#  'bortezomib': 3876,
#  'oxetorone': 143,
#  'mustard oil': 1,
#  'saccharin': 48,
#  'levomethadyl': 3,
#  'ethanolamine oleate': 1,
#  'tioconazole': 146,
#  'dienogest': 224,
#  'glycyrrhizinate': 111,
#  'alfalfa oil': 91,
#  'mexiletine': 1202,
#  'lysozyme': 252,
#  'oregano oil': 19,
#  'loratadine': 5008,
#  'petrolatum': 1179,
#  'nitroprusside': 556,
#  'primidone': 2081,
#  'sodium acetate': 116,
#  'dicyclomine': 2733,
#  'allylestrenol': 27,
#  'sorafenib': 2779,
#  'diacetyl benzoyl lathyrol': 39,
#  'quetiapine': 6172,
#  'drug_concept_name': 1,
#  'levonorgestrel': 3194,
#  'zinc sulfate': 854,
#  'sulconazole': 48,
#  'cabazitaxel': 663,
#  'gadobutrol': 452,
#  'erythromycin': 3272,
#  'belladonna leaf extract': 62,
#  'metoprolol': 8325,
#  'canakinumab': 703,
#  'lapatinib': 2324,
#  'melitracen': 27,
#  'lactobacillus': 575,
#  'fidaxomicin': 316,
#  'homatropine': 143,
#  'tetracaine': 519,
#  'dofetilide': 1401,
#  'linaclotide': 1298,
#  'yohimbine': 8,
#  'dequalinium': 9,
#  'deflazacort': 1325,
#  'eugenol': 21,
#  'gentian violet': 21,
#  'danthron': 5,
#  'ammonium': 16,
#  'mipomersen': 121,
#  'arginine': 518,
#  'glucomannan': 13,
#  'ambroxol-theophylline-7-acetate': 14,
#  'chlorzoxazone': 794,
#  'triptorelin': 964,
#  'calcium aspartate': 676,
#  'influenza virus vaccine, inactivated a-brisbane-59-2007, ivr-148 (h1n1) strain': 314,
#  'lactase': 514,
#  'posaconazole': 1239,
#  'silicon dioxide': 29,
#  'pentoxifylline': 1953,
#  'carbocysteine': 1878,
#  'hawthorn berry': 22,
#  'alprostadil': 1228,
#  'aprepitant': 1798,
#  'chlorquinaldol': 7,
#  'moxonidine': 1465,
#  'lecithin': 621,
#  'vandetanib': 573,
#  'chloride hexahydrate': 5,
#  'eprosartan': 855,
#  'calcium gluconate': 2484,
#  'theanine': 19,
#  'gemfibrozil': 3044,
#  'cephalothin': 133,
#  'digoxin antibodies fab fragments': 409,
#  'butoconazole': 33,
#  'griseofulvin': 353,
#  'bleomycin': 1528,
#  'omega-3 fatty acids': 2205,
#  'alizapride': 380,
#  'lumefantrine': 122,
#  'felbamate': 454,
#  'dexmethylphenidate': 835,
#  'zeaxanthin': 68,
#  'epinastine': 1112,
#  'cefamandole': 115,
#  'varenicline': 3904,
#  'citrate': 606,
#  'parsley oil': 15,
#  'clioquinol': 56,
#  'fluvastatin': 2951,
#  'cefonicid': 6,
#  'ponatinib': 1051,
#  'granisetron': 3009,
#  'tyramine': 22,
#  'dydrogesterone': 334,
#  'cabergoline': 1882,
#  'eslicarbazepine': 48,
#  'nortriptyline': 3084,
#  'botulism antitoxin a': 55,
#  'triprolidine': 67,
#  'fenoterol': 1115,
#  'pipothiazine': 40,
#  'sodium selenate': 953,
#  'isosorbide': 4179,
#  'xylometazoline': 526,
#  'hydroxocobalamin': 984,
#  'ketoprofen': 3104,
#  'nandrolone': 343,
#  'dihydroxyaluminum sodium carbonate': 787,
#  'propane': 5,
#  'rho(d) immune globulin': 780,
#  'viloxazine': 68,
#  'clobutinol': 134,
#  'glatiramer': 2899,
#  'palivizumab': 1036,
#  'molgramostim': 8,
#  'acetaminophen': 9665,
#  'sotalol': 2861,
#  'medrogestone': 15,
#  'mannitol': 1261,
#  'albiglutide': 67,
#  'tinzaparin': 1660,
#  'iodine i-131': 12,
#  'guanidine': 12,
#  'arnica extract': 11,
#  'methenolone': 97,
#  'creatine': 111,
#  'halofantrine': 39,
#  'leucine': 32,
#  'orange oil': 331,
#  'calcitonin': 927,
#  'pramoxine': 593,
#  'azelastine': 2286,
#  'metolazone': 2413,
#  'epinephrine': 3034,
#  'ganirelix': 239,
#  'baclofen': 5001,
#  'rosiglitazone': 3731,
#  'tartrate': 69,
#  'pancreas extract': 45,
#  'cinnamon oil, leaf': 686,
#  'clorazepate': 2296,
#  'ioversol': 756,
#  'meglumine': 28,
#  'lactobacillus acidophilus': 2096,
#  'choline': 554,
#  'cyanocobalamin co57': 850,
#  'pemirolast': 49,
#  'fatty acids, omega-6': 72,
#  'pumpkin seed oil': 5,
#  'arnica montana extract': 3,
#  'magaldrate': 314,
#  'diosmin': 1360,
#  'ambenonium': 177,
#  'ferrous chloride': 6,
#  'inositol': 111,
#  'pravastatin': 5217,
#  'glyburide': 4722,
#  'dronabinol': 1790,
#  'methionine': 217,
#  'carbenoxolone': 5,
#  'brinzolamide': 1311,
#  'factor viii': 845,
#  'topotecan': 1382,
#  'testosterone': 3547,
#  'naratriptan': 888,
#  'phospholipids': 32,
#  'prednazoline': 15,
#  'pirarubicin': 443,
#  'spirapril': 35,
#  'cinacalcet': 2131,
#  'clodronic acid': 342,
#  'pazopanib': 1711,
#  'tinidazole': 220,
#  'methyclothiazide': 77,
#  'darunavir': 1990,
#  'tiratricol': 11,
#  'secretin': 9,
#  'meclizine': 2916,
#  'netilmicin': 232,
#  'progesterone': 2567,
#  'hydrocortisone': 5275,
#  'lisdexamfetamine': 1596,
#  'ciclopirox': 740,
#  'aceclofenac': 567,
#  'gold': 566,
#  'glimepiride': 4621,
#  'calcium bicarbonate': 41,
#  'colloidal oatmeal': 7,
#  'propylthiouracil': 968,
#  'certoparin': 201,
#  'minoxidil': 1977,
#  'fentanyl': 6530,
#  'amikacin': 1914,
#  'peginterferon alfa-2b': 3357,
#  'brimonidine': 2342,
#  'gemtuzumab ozogamicin': 1129,
#  'propylene glycol': 346,
#  'sennoside b': 99,
#  'sulfinpyrazone': 45,
#  'fusafungin': 59,
#  'factor xiii': 65,
#  'hydroquinone': 1055,
#  'ethanol': 1554,
#  'interferon alfacon-1': 900,
#  'cuprous oxide': 464,
#  'proteins': 46,
#  'butorphanol': 788,
#  'succinylcholine': 1100,
#  'nitrous oxide': 761,
#  'lorazepam': 7340,
#  'ethinyl estradiol': 5317,
#  'air': 416,
#  'flunitrazepam': 2167,
#  'zolmitriptan': 1767,
#  'debrisoquin': 1,
#  'bencyclane': 23,
#  'tricaprylin': 54,
#  'dabigatran': 782,
#  'clozapine': 4424,
#  'lymphocyte immune globulin, anti-thymocyte globulin': 808,
#  'solifenacin': 2749,
#  'ethiodized oil': 194,
#  'ethylene oxide': 1,
#  'doxacurium': 4,
#  'human vaccinia immune globulin': 307,
#  'itraconazole': 2644,
#  'nevirapine': 2589,
#  'cyclofenil': 2,
#  'apomorphine': 862,
#  'furosemide': 8658,
#  'calcium acetate': 2066,
#  'risedronic acid': 821,
#  'oxolamine': 24,
#  'fluocinonide': 1311,
#  'prilocaine': 767,
#  'sobrerol': 7,
#  'saxagliptin': 1440,
#  'pramipexole': 3387,
#  'iron polysaccharide': 89,
#  'diflucortolone': 454,
#  'rasburicase': 539,
#  'isoetharine': 66,
#  'vitamin d3': 3025,
#  'ethamsylate': 230,
#  'eletriptan': 1584,
#  'tubocurarine': 10,
#  'duloxetine': 6300,
#  'aloe extract': 155,
#  'benzethonium': 47,
#  'aluminum phosphate': 21,
#  'ospemifene': 264,
#  'epidermal growth factor': 8,
#  'gadopentetate dimeglumine': 1418,
#  'orphenadrine': 1417,
#  'ambrisentan': 2666,
#  'methaqualone': 53,
#  'boceprevir': 2427,
#  'sodium fluoride': 1053,
#  'articaine': 355,
#  'streptomycin': 596,
#  'pyrimethamine': 716,
#  'oxymetholone': 173,
#  'vitamin d': 6559,
#  'silver nitrate': 74,
#  'copper': 802,
#  'sulfasalazine': 3973,
#  'pholcodine': 313,
#  'flutamide': 868,
#  'atorvastatin': 8344,
#  'alendronate': 6820,
#  'iloperidone': 446,
#  'acitretin': 1397,
#  'sodium gluconate': 61,
#  'mequinol': 16,
#  'cysteamine': 248,
#  'pitavastatin': 1323,
#  'yellow fever vaccine': 92,
#  'loracarbef': 157,
#  'diethylpropion': 203,
#  'codeine': 4814,
#  'plerixafor': 412,
#  'imidapril': 888,
#  'somatropin': 3219,
#  'aminolevulinate': 44,
#  'propiomazine': 467,
#  'lynestrenol': 193,
#  'belladonna alkaloids': 191,
#  'tyloxapol': 4,
#  'samarium': 16,
#  'dienestrol': 2,
#  'azithromycin': 5218,
#  'buclizine': 76,
#  'nivolumab': 117,
#  'naloxone': 1945,
#  'peginterferon alfa-2a': 3790,
#  'bee pollen': 116,
#  'desipramine': 951,
#  'chlorambucil': 1227,
#  'propolis': 52,
#  'fosinopril': 2637,
#  'lavender oil': 12,
#  'ascorbic acid': 4679,
#  'gestodene': 265,
#  'eplerenone': 1479,
#  'berberine': 52,
#  'bcg, live, tice strain': 399,
#  'iohexol': 1235,
#  'eflornithine': 316,
#  'guanfacine': 1216,
#  'acenocoumarol': 2202,
#  'sulfanilamide': 29,
#  'cytarabine': 3538,
#  'idursulfase': 520,
#  'carboxymethylcellulose': 674,
#  'melatonin': 2301,
#  'olmesartan': 4597,
#  'pipamperone': 799,
#  'timothy grass pollen extract': 50,
#  'clofoctol': 7,
#  'pegvisomant': 556,
#  'triamcinolone': 4261,
#  'venlafaxine': 6642,
#  'acepromazine': 75,
#  'arsenic': 84,
#  'lopinavir': 1611,
#  'dibasic potassium phosphate': 144,
#  'empagliflozin': 107,
#  'sufentanil': 1249,
#  'thiamine': 2596,
#  'dextran 110': 94,
#  'chlorophyll': 126,
#  'dimethyl fumarate': 2195,
#  'iso-sulfan blue': 51,
#  'salmon oil': 341,
#  'maltose': 388,
#  'eszopiclone': 2932,
#  'prednisone': 9289,
#  'levomilnacipran': 169,
#  'grapefruit seed extract': 13,
#  'iodoquinol': 4,
#  'fenoprofen': 125,
#  'trenbolone': 12,
#  'iodixanol': 736,
#  'bifidobacterium longum': 235,
#  'pemetrexed': 2272,
#  'silymarin': 947,
#  'methimazole': 1777,
#  'ticarcillin': 113,
#  'clonazepam': 7237,
#  'amorolfine': 188,
#  'cephradine': 206,
#  'ginkgo biloba leaf extract': 113,
#  'irbesartan': 4591,
#  'vinblastine': 1319,
#  'emu oil': 17,
#  'palifermin': 348,
#  'tropicamide': 518,
#  'niaprazine': 15,
#  'chromic chloride': 5,
#  'methysergide': 215,
#  'deslanoside': 76,
#  'lindane': 224,
#  'iobenguane i-123': 4,
#  'etifoxine': 354,
#  'milk thistle seed extract': 5,
#  'mianserin': 1405,
#  'pimobendan': 278,
#  'aldesleukin': 933,
#  'ferric hydroxide': 171,
#  'fish oils': 187,
#  'evening primrose oil': 495,
#  'cimetidine': 2839,
#  'ephedrine': 945,
#  'triazulenone': 77,
#  'mesoridazine': 87,
#  'leuprolide': 3919,
#  'l1 protein, human papillomavirus type 58 vaccine': 10,
#  'phenprocoumon': 2386,
#  'cocaine': 1416,
#  'difenoxin': 29,
#  'oseltamivir': 2200,
#  'phenacemide': 13,
#  'thiamphenicol': 28,
#  'azathioprine': 5550,
#  'rituximab': 5268,
#  'tiropramide': 14,
#  'lysine': 1073,
#  'orange juice': 1,
#  'felbinac': 650,
#  'clobetasone': 302,
#  'heptaminol': 435,
#  'dexbrompheniramine': 787,
#  'telmisartan': 3761,
#  'alosetron': 494,
#  'talc': 51,
#  'deanol': 19,
#  'potassium ascorbate': 42,
#  'cloprednol': 33,
#  'acetylcholine': 47,
#  'histrelin': 307,
#  'zinc pyrithione': 67,
#  'magnesium chloride': 2852,
#  'nitrofurantoin': 3371,
#  'miconazole': 1682,
#  'moricizine': 68,
#  'magnesium lactate': 121,
#  'phentermine': 1607,
#  'beractant': 322,
#  'sodium thiosulfate': 149,
#  'nicorandil': 2155,
#  'penicillin': 2673,
#  'phenylbutyrate': 239,
#  'lithium acetate': 136,
#  'mizolastine': 136,
#  'ceftriaxone': 4369,
#  'pyrethrins': 168,
#  'carbon black': 10,
#  'bismuth subcarbonate': 8,
#  'copper sulfate': 25,
#  'metaxalone': 2606,
#  'thymus oil': 3,
#  'brentuximab vedotin': 908,
#  'nilutamide': 297,
#  'helium': 16,
#  'gliquidone': 184,
#  'enoxacin': 69,
#  'ajmaline': 183,
#  'doxapram': 56,
#  'demecarium': 20,
#  'methazolamide': 168,
#  'paricalcitol': 1831,
#  'tofisopam': 274,
#  'megestrol': 2858,
#  'thiopental': 969,
#  'chloroprocaine': 44,
#  'trandolapril': 2132,
#  'adenine': 38,
#  'nefopam': 1237,
#  'ammonium chloride': 71,
#  'dimethindene': 629,
#  'toremifene': 474,
#  'lutetium': 20,
#  'cefdinir': 1916,
#  'benoxinate': 86,
#  'clofibrate': 52,
#  'efinaconazole': 18,
#  'cefotaxime': 1773,
#  'imipramine': 2213,
#  'decanoic acid': 3,
#  'hydralazine': 2967,
#  'ivabradine': 785,
#  'tiemonium': 29,
#  'imiglucerase': 1406,
#  'nadroparin': 965,
#  'magnesium salt': 70,
#  'saw palmetto extract': 797,
#  'cytosine': 416,
#  'enoximone': 23,
#  'phenylacetate': 63,
#  'fosfestrol': 78,
#  'carbinoxamine': 260,
#  'sodium ferric gluconate complex': 913,
#  'sofosbuvir': 1268,
#  'butylscopolamine': 1361,
#  'lithium carbonate': 3608,
#  'irinotecan': 2918,
#  'nitisinone': 200,
#  'bismuth subsalicylate': 889,
#  'mirtazapine': 4982,
#  'prasugrel': 1500,
#  'calfactant': 22,
#  'strontium-89': 202,
#  'polidocanol': 183,
#  'dyphylline': 90,
#  'flubendazole': 5,
#  'lemon oil': 7,
#  'amoxicillin': 5461,
#  'tolvaptan': 839,
#  'tocopheryl nicotinate, d-.alpha.': 536,
#  'dolutegravir': 421,
#  'tuberculin': 177,
#  'lacidipine': 551,
#  'primaquine': 276,
#  'veralipride': 31,
#  'potassium bitartrate': 47,
#  'reproterol': 37,
#  'isoniazid': 3109,
#  'lactobacillus casei': 108,
#  'streptococcus pyogenes': 18,
#  'romidepsin': 279,
#  'clocortolone': 144,
#  'polysorbate 80': 7,
#  'ibritumomab tiuxetan': 821,
#  'spiramycin': 511,
#  'tacrine': 33,
#  'papaveretum': 5,
#  'menadiol': 13,
#  'didanosine': 2165,
#  'troleandomycin': 9,
#  'mupirocin': 2005,
#  'bromperidol': 231,
#  'paraldehyde': 41,
#  'cadexomer iodine': 61,
#  'lucinactant': 1,
#  'ergonovine': 70,
#  'metyrapone': 188,
#  'trimeprazine': 1071,
#  'cefoxitin': 539,
#  'isopropyl unoprostone': 14,
#  'rifaximin': 1143,
#  'stannous fluoride': 152,
#  'goserelin': 2281,
#  'rotigotine': 1121,
#  'ibrutinib': 783,
#  'betaxolol': 1297,
#  'formaldehyde': 29,
#  'oregano leaf oil': 53,
#  'talinolol': 82,
#  'nabumetone': 2603,
#  'terbinafine': 3036,
#  'meclofenoxate': 19,
#  'vincristine': 4237,
#  'chitosan': 22,
#  'radium chloride ra-223': 242,
#  'lorcaserin': 313,
#  'phenindione': 26,
#  'icodextrin': 304,
#  'metronidazole': 5119,
#  'armodafinil': 1823,
#  'acemetacin': 418,
#  'salsalate': 923,
#  'pregabalin': 6308,
#  'cefoperazone': 736,
#  'cisplatin': 4090,
#  'thiethylperazine': 308,
#  'phosphatidylserine': 34,
#  'etomidate': 763,
#  'sparfloxacin': 74,
#  'roflumilast': 1015,
#  'vismodegib': 473,
#  'fenspiride': 274,
#  'malathion': 1151,
#  'gamma-aminobutyrate': 30,
#  'atracurium': 659,
#  'mosapride': 1505,
#  'fibrinogen': 313,
#  'naphazoline': 254,
#  'procaine': 425,
#  'dobutamine': 1504,
#  'theophylline': 3431,
#  'methscopolamine': 205,
#  'bromine': 4,
#  'pantothenate': 119,
#  'glutamate': 95,
#  'alexitol': 11,
#  'zinc acetate': 150,
#  'trihexyphenidyl': 1794,
#  'idebenone': 37,
#  'pantothenic acid': 130,
#  'mycophenolic acid': 2629,
#  'thyroid (usp)': 2517,
#  'methenamine': 622,
#  'decitabine': 1058,
#  'oprelvekin': 278,
#  'zanamivir': 735,
#  'practolol': 6,
#  'ferrous carbonate': 14,
#  'deferoxamine': 1095,
#  'heparin': 5075,
#  'hypericum extract': 96,
#  'basil oil': 16,
#  'pamidronate': 3734,
#  'calcium phosphate dibasic': 16,
#  'magnesium oxide': 4271,
#  'streptokinase': 291,
#  'loxapine': 1024,
#  'pentobarbital': 325,
#  'fluorometholone': 713,
#  'omalizumab': 2623,
#  'sulfisoxazole': 76,
#  'zinc orotate': 8,
#  'human skin preparation': 84,
#  'omega-3 acid ethyl esters (usp)': 2497,
#  'rimantadine': 217,
#  'pertuzumab': 759,
#  'argatroban': 713,
#  'typhoid vaccine live ty21a': 9,
#  'regadenoson': 516,
#  'methsuximide': 100,
#  'hexobarbital': 5,
#  'estradiol': 4973,
#  'meperidine': 2914,
#  'magnesium glycinate': 39,
#  'mecobalamin': 2105,
#  'adrenal cortex extract': 5,
#  'potassium sulfate': 13,
#  'dipipanone': 1,
#  'amphotericin': 179,
#  'amisulpride': 1650,
#  'gadoterate meglumine': 341,
#  'valrubicin': 89,
#  'lanreotide': 747,
#  'metreleptin': 7,
#  'antilymphocyte immunoglobulin': 106,
#  'polygeline': 31,
#  'ornidazole': 225,
#  'quinidine': 950,
#  'ethenzamide': 22,
#  'zuclopenthixol': 1067,
#  'saccharomyces cerevisiae': 374,
#  'blueberry extract': 2,
#  'ethylene': 2,
#  '2-mercaptoethanesulfonic acid': 5,
#  'magnesium carbonate': 340,
#  'valganciclovir': 2352,
#  'asparagine': 18,
#  'trametinib': 459,
#  'chlorothiazide': 708,
#  'desoximetasone': 574,
#  'norgestrel': 371,
#  'oxaliplatin': 3244,
#  'ocriplasmin': 80,
#  'clotiazepam': 927,
#  'zopiclone': 4313,
#  'calcium carbonate, precipitated': 396,
#  'phenacetin': 41,
#  'charcoal': 106,
#  'glipizide': 4414,
#  'sulfacetamide': 318,
#  'rilpivirine': 362,
#  'metformin': 7778,
#  'fusidate': 1013,
#  'opipramol': 702,
#  'pralatrexate': 279,
#  'psyllium': 2222,
#  'cascara sagrada': 85,
#  'polymyxin b': 857,
#  'methyldopate': 19,
#  'daunorubicin liposomal': 126,
#  'mibefradil': 49,
#  'risperidone': 5303,
#  'sodium': 380,
#  'zotepine': 461,
#  'balsalazide': 942,
#  'docusate': 5264,
#  'paregoric': 147,
#  'garlic preparation': 40,
#  'frovatriptan': 641,
#  'bepridil': 312,
#  'cyclopentolate': 449,
#  'aztreonam': 1019,
#  'proguanil': 997,
#  'ethchlorvynol': 34,
#  'flunarizine': 388,
#  'cefodizime': 3,
#  'silicon dioxide, colloidal': 9,
#  'oxytetracycline': 512,
#  'fluorescein': 431,
#  'glycerin': 1411,
#  'capecitabine': 4144,
#  'atovaquone': 1224,
#  'sapropterin': 506,
#  'diflorasone': 339,
#  'acyclovir': 5385,
#  'succinate': 26,
#  'verapamil': 4655,
#  'zinc citrate': 6,
#  'arbekacin': 244,
#  'dexetimide': 19,
#  'orlistat': 2228,
#  'carbaryl': 3,
#  'salmon calcitonin': 2241,
#  'bromhexine': 916,
#  'thyme oil': 19,
#  'lithium chloride': 4,
#  'lodoxamide': 49,
#  'hydrogen peroxide': 286,
#  'kerosene': 3,
#  'sipuleucel-t': 891,
#  'eribulin': 656,
#  'sulfadiazine': 691,
#  'dyclonine': 54,
#  'luliconazole': 25,
#  'aminopterin': 1,
#  'lanthanum carbonate': 1260,
#  'folate': 1145,
#  'apricot kernel oil': 1,
#  'medazepam': 98,
#  'bamifylline': 341,
#  'obinutuzumab': 277,
#  'alpha tocopherol': 5,
#  'pizotyline': 328,
#  'penciclovir': 348,
#  'romiplostim': 1859,
#  'mitotane': 380,
#  'hexachlorophene': 157,
#  'mifepristone': 626,
#  'hexoprenaline': 4,
#  'carbon dioxide': 94,
#  'domperidone': 3589,
#  'midodrine': 1433,
#  'oxeladin': 22,
#  'vitamin a': 4318,
#  'polyethylene glycol 400': 783,
#  'rasagiline': 1172,
#  'isoproterenol': 279,
#  'ledipasvir': 189,
#  'pipemidate': 45,
#  'alglucosidase alfa': 974,
#  'fe heme polypeptide': 88,
#  'magnesium gluconate': 583,
#  'amphetamine': 1310,
#  'aspartate': 28,
#  'tegaserod': 2322,
#  'oxerutins': 36,
#  'calcium glycerophosphate': 52,
#  'propafenone': 1653,
#  'methohexital': 106,
#  'everolimus': 3424,
#  'methotrexate': 8326,
#  'dihydralazine': 265,
#  'paraffin': 521,
#  'indoramin': 116,
#  'grapefruit oil': 25,
#  'caffeine': 2989,
#  'metaproterenol': 2054,
#  'phenazopyridine': 1813,
#  'promegestone': 24,
#  'aspirin': 9805,
#  'zinc chloride': 21,
#  'ethynodiol': 14,
#  'anidulafungin': 403,
#  'methylnaltrexone': 350,
#  'buflomedil': 741,
#  'ox bile extract': 5,
#  'eculizumab': 2765,
#  'insulin lispro': 4637,
#  'tretinoin': 1696,
#  'canrenoate': 747,
#  'amoxapine': 816,
#  'meclofenamate': 162,
#  'cycloserine': 282,
#  'betaine, anhydrous': 16,
#  'potassium chlorate': 80,
#  'citric acid': 324,
#  'red yeast rice': 552,
#  'chloride ion': 119,
#  'serratiopeptidase': 17,
#  'methyltestosterone': 155,
#  'dihydroxyacetone': 21,
#  'desloratadine': 2846,
#  'galantamine': 1544,
#  'peanut oil': 39,
#  'belimumab': 1304,
#  'meprobamate': 1405,
#  'citrulline': 123,
#  'lactulose': 4004,
#  'ethylene glycol': 174,
#  'ibandronate': 3670,
#  '2-hydroxyethyl methacrylate': 44,
#  'phosphorus 32': 30,
#  'escin': 19,
#  'indinavir': 1069,
#  'methanol': 112,
#  'zalcitabine': 361,
#  'deserpidine': 30,
#  'iobitridol': 154,
#  'cefotetan': 221,
#  'cinnamon oil': 12,
#  'heme iron polypeptide': 7,
#  'diazoxide': 297,
#  'asparaginase': 1726,
#  'budesonide': 4806,
#  'lixisenatide': 30,
#  'loteprednol etabonate': 972,
#  'tramadol': 6729,
#  'phenethylamine': 14,
#  'dirithromycin': 96,
#  'epirubicin': 2359,
#  'barium': 111,
#  'potassium phosphate': 395,
#  'cefmetazole': 136,
#  'dipyrone': 2303,
#  'carbidopa': 2526,
#  'etonogestrel': 1761,
#  'thioridazine': 1084,
#  'ubiquinol': 103,
#  'tiagabine': 1210,
#  'vindesine': 607,
#  'arformoterol': 729,
#  'pomegranate juice': 6,
#  'furazolidone': 36,
#  'praziquantel': 125,
#  'sargramostim': 949,
#  'passiflora incarnata extract': 2,
#  'hyoscyamine': 2301,
#  'cefotiam': 784,
#  'natalizumab': 5153,
#  'mercaptopurine': 2830,
#  'ropinirole': 3265,
#  'tetrazepam': 1272,
#  'montelukast': 5631,
#  'interferon alfa-2b': 2068,
#  'temocillin': 16,
#  'tacalcitol': 50,
#  'hetastarch': 231,
#  'chlorpromazine': 2589,
#  'belatacept': 545,
#  'zolpidem': 7414,
#  'tilidine': 728,
#  'amphotericin b': 2401,
#  'nisoldipine': 1063,
#  'immunoglobulin a': 1319,
#  'lamotrigine': 5704,
#  'lobeline': 4,
#  'papaverine': 459,
#  'vilanterol': 497,
#  'distigmine': 484,
#  'etilefrine': 201,
#  'clindamycin': 4108,
#  'lenograstim': 1305,
#  'sodium tetradecyl sulfate': 88,
#  'iopamidol': 1062,
#  'methylergonovine': 561,
#  'hydrotalcite': 39,
#  'umeclidinium': 145,
#  'polihexanide': 8,
#  'estriol': 555,
#  'tropatepine': 258,
#  'succinic acid': 272,
#  'thymopentin': 12,
#  'chondroitin sulfate (chicken)': 490,
#  'japanese encephalitis virus vaccine, inactivated': 7,
#  'coenzyme q10': 2254,
#  'cladribine': 786,
#  'crofelemer': 7,
#  'carbazochrome': 1098,
#  'tulobuterol': 1043,
#  'retapamulin': 276,
#  'tesamorelin': 472,
#  'lithium': 2774,
#  'ornithine': 155,
#  'benproperine': 24,
#  'diflunisal': 644,
#  'thallium': 80,
#  'cefazolin': 2790,
#  'potassium': 4528,
#  'ethacrynate': 310,
#  ...}

# %%
df['NoSideEffects'] = df['DRUG_NAME'].str.lower().map(drugsymp)

# %%
df
# Out:
#                          DRUG_NAME  DRUG_ID  \
# 0                      Salinomycin  DB11544
# 1    tenofovir disoproxil fumarate  DB00300
# 2                       Tipranavir  DB00932
# 3                      Clopidogrel  DB00758
# 4                      artemisinin  DB13132
# ..                             ...      ...
# 280                     Raloxifene  DB00481
# 281                      Quercetin  DB04216
# 282                   Vildagliptin  DB04876
# 283                   Mitoxantrone  DB01204
# 284                 Mercaptopurine  DB01033
#
#                                                 SMILES  NoSideEffects
# 0    [H][C@@](C)(C(=O)[C@]([H])(CC)[C@@]1([H])O[C@@...            NaN
# 1    [H][C@@](C)(CN1C=NC2=C(N)N=CN=C12)OCP(=O)(OCOC...            NaN
# 2    [H][C@@](CC)(C1=CC(NS(=O)(=O)C2=NC=C(C=C2)C(F)...          835.0
# 3    [H][C@@](N1CCC2=C(C1)C=CS2)(C(=O)OC)C1=CC=CC=C1Cl         6553.0
# 4    [H][C@@]1(C)CC[C@@]2([H])[C@@]([H])(C)C(=O)O[C...            NaN
# ..                                                 ...            ...
# 280  OC1=CC=C(C=C1)C1=C(C(=O)C2=CC=C(OCCN3CCCCC3)C=...         3298.0
# 281  OC1=CC2=C(C(O)=C1)C(=O)C(O)=C(O2)C1=CC=C(O)C(O...           97.0
# 282       OC12CC3CC(C1)CC(C3)(C2)NCC(=O)N1CCC[C@H]1C#N         1004.0
# 283  OCCNCCNC1=CC=C(NCCNCCO)C2=C1C(=O)C1=C(C(O)=CC=...         2178.0
# 284                                 S=C1N=CNC2=C1NC=N2         2830.0
#
# [285 rows x 4 columns]

# %%
drugsympall={}

for i in range(length):
    key=drugname[i].lower()
    value=side_eff[i]
    drugsympall[key]=value

# %%
df['AllSideEffects'] = df['DRUG_NAME'].str.lower().map(drugsympall)

# %%
df
# Out:
#                          DRUG_NAME  DRUG_ID  \
# 0                      Salinomycin  DB11544
# 1    tenofovir disoproxil fumarate  DB00300
# 2                       Tipranavir  DB00932
# 3                      Clopidogrel  DB00758
# 4                      artemisinin  DB13132
# ..                             ...      ...
# 280                     Raloxifene  DB00481
# 281                      Quercetin  DB04216
# 282                   Vildagliptin  DB04876
# 283                   Mitoxantrone  DB01204
# 284                 Mercaptopurine  DB01033
#
#                                                 SMILES  NoSideEffects  \
# 0    [H][C@@](C)(C(=O)[C@]([H])(CC)[C@@]1([H])O[C@@...            NaN
# 1    [H][C@@](C)(CN1C=NC2=C(N)N=CN=C12)OCP(=O)(OCOC...            NaN
# 2    [H][C@@](CC)(C1=CC(NS(=O)(=O)C2=NC=C(C=C2)C(F)...          835.0
# 3    [H][C@@](N1CCC2=C(C1)C=CS2)(C(=O)OC)C1=CC=CC=C1Cl         6553.0
# 4    [H][C@@]1(C)CC[C@@]2([H])[C@@]([H])(C)C(=O)O[C...            NaN
# ..                                                 ...            ...
# 280  OC1=CC=C(C=C1)C1=C(C(=O)C2=CC=C(OCCN3CCCCC3)C=...         3298.0
# 281  OC1=CC2=C(C(O)=C1)C(=O)C(O)=C(O2)C1=CC=C(O)C(O...           97.0
# 282       OC12CC3CC(C1)CC(C3)(C2)NCC(=O)N1CCC[C@H]1C#N         1004.0
# 283  OCCNCCNC1=CC=C(NCCNCCO)C2=C1C(=O)C1=C(C(O)=CC=...         2178.0
# 284                                 S=C1N=CNC2=C1NC=N2         2830.0
#
#                                         AllSideEffects
# 0                                                  NaN
# 1                                                  NaN
# 2    ['Anaemia', 'Normochromic normocytic anaemia',...
# 3    ['Anaemia vitamin B12 deficiency', 'Deficiency...
# 4                                                  NaN
# ..                                                 ...
# 280  ['Anaemia vitamin B12 deficiency', 'Iron defic...
# 281  ['Anaemia', 'Coagulopathy', 'Dizziness', 'Pres...
# 282  ['Iron deficiency anaemia', 'Anaemia', 'Haemor...
# 283  ['Iron deficiency anaemia', 'Anaemia', 'Anaemi...
# 284  ['Iron deficiency anaemia', 'Anaemia', 'Anaemi...
#
# [285 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# DRUG_NAME           0
# DRUG_ID             0
# SMILES              0
# NoSideEffects     112
# AllSideEffects    112
# dtype: int64

# %%
df.dropna(subset = ["NoSideEffects"], inplace=True)

# %%
df.rename(columns = {'NoSideEffects':'NoSideEffects_OffSide'}, inplace = True)
df.rename(columns = {'AllSideEffects':'AllSideEffects_OffSidde'}, inplace = True)

# %%
df
# Out:
#           DRUG_NAME  DRUG_ID  \
# 2        Tipranavir  DB00932
# 3       Clopidogrel  DB00758
# 5    clarithromycin  DB01211
# 6        valrubicin  DB00385
# 9       Dutasteride  DB01126
# ..              ...      ...
# 280      Raloxifene  DB00481
# 281       Quercetin  DB04216
# 282    Vildagliptin  DB04876
# 283    Mitoxantrone  DB01204
# 284  Mercaptopurine  DB01033
#
#                                                 SMILES  NoSideEffects_OffSide  \
# 2    [H][C@@](CC)(C1=CC(NS(=O)(=O)C2=NC=C(C=C2)C(F)...                  835.0
# 3    [H][C@@](N1CCC2=C(C1)C=CS2)(C(=O)OC)C1=CC=CC=C1Cl                 6553.0
# 5    [H][C@@]1(C[C@@](C)(OC)[C@@H](O)[C@H](C)O1)O[C...                 4329.0
# 6    [H][C@@]1(C[C@@](O)(CC2=C(O)C3=C(C(O)=C12)C(=O...                   89.0
# 9    [H][C@@]1(CC[C@@]2([H])[C@]3([H])CC[C@@]4([H])...                 2641.0
# ..                                                 ...                    ...
# 280  OC1=CC=C(C=C1)C1=C(C(=O)C2=CC=C(OCCN3CCCCC3)C=...                 3298.0
# 281  OC1=CC2=C(C(O)=C1)C(=O)C(O)=C(O2)C1=CC=C(O)C(O...                   97.0
# 282       OC12CC3CC(C1)CC(C3)(C2)NCC(=O)N1CCC[C@H]1C#N                 1004.0
# 283  OCCNCCNC1=CC=C(NCCNCCO)C2=C1C(=O)C1=C(C(O)=CC=...                 2178.0
# 284                                 S=C1N=CNC2=C1NC=N2                 2830.0
#
#                                AllSideEffects_OffSidde
# 2    ['Anaemia', 'Normochromic normocytic anaemia',...
# 3    ['Anaemia vitamin B12 deficiency', 'Deficiency...
# 5    ['Deficiency anaemia', 'Iron deficiency anaemi...
# 6    ['Leukocytosis', 'Dizziness', 'Dyspnoea', 'Vis...
# 9    ['Anaemia vitamin B12 deficiency', 'Iron defic...
# ..                                                 ...
# 280  ['Anaemia vitamin B12 deficiency', 'Iron defic...
# 281  ['Anaemia', 'Coagulopathy', 'Dizziness', 'Pres...
# 282  ['Iron deficiency anaemia', 'Anaemia', 'Haemor...
# 283  ['Iron deficiency anaemia', 'Anaemia', 'Anaemi...
# 284  ['Iron deficiency anaemia', 'Anaemia', 'Anaemi...
#
# [173 rows x 5 columns]

# %%
df.to_csv('NEW_Table_5B_300_Offside_drugmaped.csv', index=False)

# %%
df['AllSideEffects_OffSidde'].count()
# Out:
# 173

# %%
df #[(df['NoSideEffects']!='NaN')]
#df[(df['Train'] != 'DeutscheBahn')
# Out:
#           DRUG_NAME  DRUG_ID  \
# 2        Tipranavir  DB00932
# 3       Clopidogrel  DB00758
# 5    clarithromycin  DB01211
# 6        valrubicin  DB00385
# 9       Dutasteride  DB01126
# ..              ...      ...
# 280      Raloxifene  DB00481
# 281       Quercetin  DB04216
# 282    Vildagliptin  DB04876
# 283    Mitoxantrone  DB01204
# 284  Mercaptopurine  DB01033
#
#                                                 SMILES  NoSideEffects_OffSide  \
# 2    [H][C@@](CC)(C1=CC(NS(=O)(=O)C2=NC=C(C=C2)C(F)...                  835.0
# 3    [H][C@@](N1CCC2=C(C1)C=CS2)(C(=O)OC)C1=CC=CC=C1Cl                 6553.0
# 5    [H][C@@]1(C[C@@](C)(OC)[C@@H](O)[C@H](C)O1)O[C...                 4329.0
# 6    [H][C@@]1(C[C@@](O)(CC2=C(O)C3=C(C(O)=C12)C(=O...                   89.0
# 9    [H][C@@]1(CC[C@@]2([H])[C@]3([H])CC[C@@]4([H])...                 2641.0
# ..                                                 ...                    ...
# 280  OC1=CC=C(C=C1)C1=C(C(=O)C2=CC=C(OCCN3CCCCC3)C=...                 3298.0
# 281  OC1=CC2=C(C(O)=C1)C(=O)C(O)=C(O2)C1=CC=C(O)C(O...                   97.0
# 282       OC12CC3CC(C1)CC(C3)(C2)NCC(=O)N1CCC[C@H]1C#N                 1004.0
# 283  OCCNCCNC1=CC=C(NCCNCCO)C2=C1C(=O)C1=C(C(O)=CC=...                 2178.0
# 284                                 S=C1N=CNC2=C1NC=N2                 2830.0
#
#                                AllSideEffects_OffSidde
# 2    ['Anaemia', 'Normochromic normocytic anaemia',...
# 3    ['Anaemia vitamin B12 deficiency', 'Deficiency...
# 5    ['Deficiency anaemia', 'Iron deficiency anaemi...
# 6    ['Leukocytosis', 'Dizziness', 'Dyspnoea', 'Vis...
# 9    ['Anaemia vitamin B12 deficiency', 'Iron defic...
# ..                                                 ...
# 280  ['Anaemia vitamin B12 deficiency', 'Iron defic...
# 281  ['Anaemia', 'Coagulopathy', 'Dizziness', 'Pres...
# 282  ['Iron deficiency anaemia', 'Anaemia', 'Haemor...
# 283  ['Iron deficiency anaemia', 'Anaemia', 'Anaemi...
# 284  ['Iron deficiency anaemia', 'Anaemia', 'Anaemi...
#
# [173 rows x 5 columns]

# %%
contain_values = df[df['DRUG_NAME'].str.contains('Mercaptopurine')]
contain_values #['AllSideEffects']
# Out:
#           DRUG_NAME  DRUG_ID              SMILES  NoSideEffects_OffSide  \
# 284  Mercaptopurine  DB01033  S=C1N=CNC2=C1NC=N2                 2830.0
#
#                                AllSideEffects_OffSidde
# 284  ['Iron deficiency anaemia', 'Anaemia', 'Anaemi...

# %%
df_OffSide=pd.read_csv("NEW_Table_8B_Offsider_DrugwithTarget_5nearDrugs_Scored.tsv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-56-b1ba9958966d> in <module>
# ----> 1 df_OffSide=pd.read_csv("NEW_Table_8B_Offsider_DrugwithTarget_5nearDrugs_Scored.tsv")
#
# c:\users\prateekpaul\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# c:\users\prateekpaul\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# c:\users\prateekpaul\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# c:\users\prateekpaul\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# c:\users\prateekpaul\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# c:\users\prateekpaul\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# c:\users\prateekpaul\appdata\local\programs\python\python39\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'NEW_Table_8B_Offsider_DrugwithTarget_5nearDrugs_Scored.tsv'

# %%
df_OffSide

# %%
df_OffSide.rename(columns = {'drugname':'DRUG_NAME'}, inplace = True)
df_OffSide

# %%
df["DRUG_NAME"]=df["DRUG_NAME"].str.lower()

# %%
#df.dropna(subset = ["NoSideEffects"], inplace=True)

# %%
df

# %%
df_merge_col = pd.merge(df, df_OffSide, on='DRUG_NAME')

# %%
df_merge_col

# %%
len(df_merge_col['DRUG_NAME'].unique())

# %%
df_merge_col.to_csv('Table_5B_300_Offside53_5LikeDrug_with_Target.csv', index=False)
