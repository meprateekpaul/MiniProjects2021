# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
def mapping(df,dfkey,dfvalue):
    key=dfkey
    value=dfvalue
    dictionary={}

    for i in range(len(df)):
        dictionary[key[i]]=value[i]
        
    return dictionary

# %%
df = pd.read_csv('Table_13A_True_Negetive_Sider.csv')
length=len(df)

# %%
df
# Out:
#         CID_mainD       drugname  \
# 0    CID100032281     Protirelin
# 1    CID100032281     Protirelin
# 2    CID100132971    abiraterone
# 3    CID100041774       acarbose
# 4    CID100000187  acetylcholine
# ..            ...            ...
# 181  CID113559279     ulipristal
# 182  CID113559279     ulipristal
# 183  CID100013342    vinblastine
# 184  CID124776445     vismodegib
# 185  CID100005311     vorinostat
#
#                                                Smiles1  \
# 0    C1C[C@H](N(C1)C(=O)[C@H](CC2=CN=CN2)NC(=O)[C@@...
# 1    C1C[C@H](N(C1)C(=O)[C@H](CC2=CN=CN2)NC(=O)[C@@...
# 2    C[C@]12CC[C@@H](CC1=CC[C@@H]3[C@@H]2CC[C@]4([C...
# 3    C[C@@H]1C(C([C@H]([C@H](O1)O[C@@H]2[C@H](OC(C(...
# 4                                 CC(=O)OCC[N+](C)(C)C
# ..                                                 ...
# 181  CC(=O)[C@]1(CC[C@@H]2[C@@]1(CC(C3=C4CCC(=O)C=C...
# 182  CC(=O)[C@]1(CC[C@@H]2[C@@]1(CC(C3=C4CCC(=O)C=C...
# 183  CC[C@]1(C[C@H]2C[C@](C3=C(CCN(C2)C1)C4=CC=CC=C...
# ...

# %%
Drug1_Target_Name=df['Drug1_Target_Name']
Drug2_Target_Name=df['Drug2_Target_Name']

dct={}

for i in tqdm(range(len(df))):
    value = 0
    if Drug1_Target_Name[i]==Drug2_Target_Name[i]:
        value = 1
    else:
        value = 0
    
    dct[i]=value
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 186/186 [00:00<00:00, 46642.39it/s]

# %%
df['Matching_Score'] = df.index.to_series().map(dct)

# %%
df
# Out:
#         CID_mainD       drugname  \
# 0    CID100032281     Protirelin
# 1    CID100032281     Protirelin
# 2    CID100132971    abiraterone
# 3    CID100041774       acarbose
# 4    CID100000187  acetylcholine
# ..            ...            ...
# 181  CID113559279     ulipristal
# 182  CID113559279     ulipristal
# 183  CID100013342    vinblastine
# 184  CID124776445     vismodegib
# 185  CID100005311     vorinostat
#
#                                                Smiles1  \
# 0    C1C[C@H](N(C1)C(=O)[C@H](CC2=CN=CN2)NC(=O)[C@@...
# 1    C1C[C@H](N(C1)C(=O)[C@H](CC2=CN=CN2)NC(=O)[C@@...
# 2    C[C@]12CC[C@@H](CC1=CC[C@@H]3[C@@H]2CC[C@]4([C...
# 3    C[C@@H]1C(C([C@H]([C@H](O1)O[C@@H]2[C@H](OC(C(...
# 4                                 CC(=O)OCC[N+](C)(C)C
# ..                                                 ...
# 181  CC(=O)[C@]1(CC[C@@H]2[C@@]1(CC(C3=C4CCC(=O)C=C...
# 182  CC(=O)[C@]1(CC[C@@H]2[C@@]1(CC(C3=C4CCC(=O)C=C...
# 183  CC[C@]1(C[C@H]2C[C@](C3=C(CCN(C2)C1)C4=CC=CC=C...
# ...

# %%
df['Matching_Score'].value_counts()
# Out:
# 0    161
# 1     25
# Name: Matching_Score, dtype: int64

# %%
df = df.sort_values("Matching_Score", ascending = False)

# %%
df
# Out:
#         CID_mainD       drugname  \
# 121  CID100004737  pentobarbital
# 83   CID100003890    latanoprost
# 164  CID100148191   temsirolimus
# 117  CID100005878    oxandrolone
# 118  CID100005878    oxandrolone
# ..            ...            ...
# 68   CID100003292       ethotoin
# 69   CID100036339      etomidate
# 70   CID100003354      flavoxate
# 72   CID100056338   fosphenytoin
# 185  CID100005311     vorinostat
#
#                                                Smiles1  \
# 121                      CCCC(C)C1(C(=O)NC(=O)NC1=O)CC
# 83   CC(C)OC(=O)CCC/C=C\C[C@H]1[C@H](C[C@H]([C@@H]1...
# 164  C[C@@H]1CC[C@H]2C[C@@H](/C(=C/C=C/C=C/[C@H](C[...
# 117  C[C@]12CC[C@H]3[C@H]([C@@H]1CC[C@]2(C)O)CC[C@@...
# 118  C[C@]12CC[C@H]3[C@H]([C@@H]1CC[C@]2(C)O)CC[C@@...
# ..                                                 ...
# 68                        CCN1C(=O)C(NC1=O)C2=CC=CC=C2
# 69               CCOC(=O)C1=CN=CN1[C@@H](C)C2=CC=CC=C2
# 70   CC1=C(OC2=C(C1=O)C=CC=C2C(=O)OCCN3CCCCC3)C4=CC...
# ...

# %%
df.to_csv('Table_13A_True_Negetive_Sider_Scored.csv', index=False)
