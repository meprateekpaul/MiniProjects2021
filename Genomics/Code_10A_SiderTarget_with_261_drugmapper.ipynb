# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
mainfile = input("Enter your Input file Name: ") #S2_Duplicates_removed.csv
neardrugtargetlist = input("Enter near drug target list: ")   #Table_8A_Sider_DrugwithTarget_5nearDrugs_Scored.tsv
sider_sideeff=input("Enter near Sider Sideeffect table: ")   #Table_2A_Sider_drug_no_effect.csv
output = input("Enter your Output file Name: ") #Table_11A_300Drug_NearDrug_Target.csv

# %%
mainfile = "S2_Duplicates_removed.csv"
neardrugtargetlist = "NEW_Table_8A_Sider_DrugwithTarget_5nearDrugs_Scored.tsv"
sider_sideeff= "NEW_Table_2B_cid_drug_no_effect.csv"
output = "NEW_Table_11A_300Drug_NearDrug_Target.csv"

# %%
df = pd.read_csv(mainfile)
length=len(df)

# %%
df=df[['DRUG_NAME','DRUG_ID','SMILES']]
df
# Out:
#        DRUG_NAME  DRUG_ID                                             SMILES
# 0    cyclosporin  DB00091  CC[C@@H]1NC(=O)[C@H]([C@H](O)[C@H](C)C\C=C\C)N...
# 1    fluvoxamine  DB00176             COCCCC\C(=N/OCCN)C1=CC=C(C=C1)C(F)(F)F
# 2     Masoprocol  DB00179  C[C@@H](CC1=CC(O)=C(O)C=C1)[C@H](C)CC1=CC(O)=C...
# 3     Bortezomib  DB00188  CC(C)C[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)C1=...
# 4       Tramadol  DB00193          COC1=CC=CC(=C1)[C@@]1(O)CCCC[C@@H]1CN(C)C
# ..           ...      ...                                                ...
# 256    Remdesvir  DB14761  CCC(CC)COC(=O)[C@H](C)N[P@](=O)(OC[C@H]1O[C@](...
# 257    EIDD-1931  DB15660   OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=CC(NO)=NC1=O
# 258    EIDD-2801  DB15661  CC(C)C(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=...
# 259    Baloxavir  DB15675  [H][C@@]12COCCN1C(=O)C1=C(O)C(=O)C=CN1N2[C@@H]...
# 260    zotatifin  DB16408  COC1=NC(OC)=C2C(O[C@]3([C@@H]([C@@H](CN(C)C)[C...
#
# [261 rows x 3 columns]

# %%
df_symp = pd.read_csv('NEW_Table_2B_cid_drug_no_effect.csv')
#length=len(df_symp)

# %%
df
# Out:
#        DRUG_NAME  DRUG_ID                                             SMILES
# 0    cyclosporin  DB00091  CC[C@@H]1NC(=O)[C@H]([C@H](O)[C@H](C)C\C=C\C)N...
# 1    fluvoxamine  DB00176             COCCCC\C(=N/OCCN)C1=CC=C(C=C1)C(F)(F)F
# 2     Masoprocol  DB00179  C[C@@H](CC1=CC(O)=C(O)C=C1)[C@H](C)CC1=CC(O)=C...
# 3     Bortezomib  DB00188  CC(C)C[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)C1=...
# 4       Tramadol  DB00193          COC1=CC=CC(=C1)[C@@]1(O)CCCC[C@@H]1CN(C)C
# ..           ...      ...                                                ...
# 256    Remdesvir  DB14761  CCC(CC)COC(=O)[C@H](C)N[P@](=O)(OC[C@H]1O[C@](...
# 257    EIDD-1931  DB15660   OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=CC(NO)=NC1=O
# 258    EIDD-2801  DB15661  CC(C)C(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=...
# 259    Baloxavir  DB15675  [H][C@@]12COCCN1C(=O)C1=C(O)C(=O)C=CN1N2[C@@H]...
# 260    zotatifin  DB16408  COC1=NC(OC)=C2C(O[C@]3([C@@H]([C@@H](CN(C)C)[C...
#
# [261 rows x 3 columns]

# %%
df_symp
# Out:
#       Unnamed: 0           CID                 drugname  no_of_side_effect  \
# 0              0  CID100002524              1,25(OH)2D3                106
# 1              1  CID100006238   17-hydroxyprogesterone                 48
# 2              2  CID100315411                  18F-FDG                  7
# 3              3  CID110107393         18F-flutemetamol                  9
# 4              4  CID104474778  2-hydroxysuccinaldehyde                 53
# ...          ...           ...                      ...                ...
# 1342        1342  CID100005731             zolmitriptan                260
# 1343        1343  CID100005732                 zolpidem                327
# 1344        1344  CID100005734               zonisamide                272
# 1345        1345  CID100005735                zopiclone                259
# 1346        1346  CID100012453           zuclopenthixol                191
#
#                                        side_effect_name
# 0     ['Abdominal cramps', 'Abdominal pain', 'Abdomi...
# 1     ['Abortion spontaneous', 'Asthenia', 'Body tem...
# 2     ['Dermatitis', 'Hyperglycaemia', 'Hypersensiti...
# 3     ['Blood pressure increased', 'Chest discomfort...
# 4     ['Acute coronary syndrome', 'Anaemia', 'Arthra...
# ...                                                 ...
# 1342  ['Abdominal pain', 'Abnormal dreams', 'Abortio...
# 1343  ['Abdominal discomfort', 'Abdominal pain', 'Ab...
# 1344  ['Abdominal pain', 'Abnormal dreams', 'Acciden...
# 1345  ['Abdominal pain', 'Abnormal behaviour', 'Abno...
# 1346  ['Abdominal pain', 'Abnormal dreams', 'Abnorma...
#
# [1347 rows x 5 columns]

# %%
drugname=df_symp["drugname"]
side_eff=df_symp["side_effect_name"]
no_side=df_symp["no_of_side_effect"]

# %%
drugsymp={}
for i in range(length):
    key=drugname[i].lower()
    value=no_side[i]
    drugsymp[key]=value

# %%
drugsymp
# Out:
# {'1,25(oh)2d3': 106,
#  '17-hydroxyprogesterone': 48,
#  '18f-fdg': 7,
#  '18f-flutemetamol': 9,
#  '2-hydroxysuccinaldehyde': 53,
#  '4-ap': 43,
#  '4-pba': 57,
#  '4-methylpyrazole': 52,
#  '5-asa': 396,
#  '5-fu': 169,
#  '5-aminolevulinic': 95,
#  "5-aza-2'-deoxycytidine": 220,
#  '5-azacytidine': 238,
#  '5-fluorocytosine': 65,
#  '5-methyltetrahydrofolate': 1,
#  '6-mercaptopurine': 58,
#  '6-thioguanine': 31,
#  '68ga': 40,
#  '8-mop': 53,
#  'a77': 103,
#  'ac1o3ha7': 3,
#  'acth(1-39': 70,
#  'alx': 43,
#  'amd3100': 61,
#  'an2690': 5,
#  'apas': 58,
#  'abarelix': 26,
#  'almeta': 16,
#  'anidulafungin': 131,
#  'asp-tyr(so3h)-met-gly-trp-met-asp-phe-nh2': 36,
#  'azarga': 70,
#  'bcnu': 177,
#  'bpti': 118,
#  'benicar-hct': 77,
#  'bivalirudin': 121,
#  'brolene': 6,
#  'buscopan': 39,
#  'cas': 337,
#  'cgp': 149,
#  'cancidas': 278,
#  'cantril': 31,
#  'carfilzomib': 65,
#  'colimycin': 85,
#  'd-cycloserine': 24,
#  'd-penicillamine': 123,
#  'dfmo': 61,
#  'dmso': 2,
#  'depreotide': 10,
#  'diane-35': 38,
#  'eaca': 55,
#  'edta': 59,
#  'enfuvirtide': 146,
#  'eptifibatide': 73,
#  'estrofem': 74,
#  'famp': 145,
#  'fk463': 171,
#  'fp-cit': 18,
#  'fty720': 93,
#  'fdurd': 72,
#  'fe(iii': 177,
#  'forteo': 109,
#  'gd-dtpa': 196,
#  'gd-eob-dtpa': 70,
#  'ge-132': 206,
#  'glat': 313,
#  'goserelin': 249,
#  'hmdp': 3,
#  'histrelin': 142,
#  'hoe': 10,
#  'humalog': 59,
#  'ici': 90,
#  'idurd': 6,
#  'implanon': 141,
#  'insulin': 188,
#  'k779': 540,
#  'kaluril': 65,
#  'l-dmp': 440,
#  'l-threo-dops': 15,
#  'lmwh': 71,
#  'ly146032': 202,
#  'lantus': 101,
#  'leuprorelin': 304,
#  'lioh': 128,
#  'lisinopril': 265,
#  'locorten': 6,
#  'lovaza': 112,
#  'lu': 42,
#  'lutalyse': 69,
#  'lyxumia': 32,
#  'mdv3100': 66,
#  'mk-462': 66,
#  'madopar': 62,
#  'meropenem': 120,
#  'mersyndol': 111,
#  'metrodin': 276,
#  'mndpdp': 27,
#  'n-acetylcysteine': 64,
#  'n-carbamylglutamate': 37,
#  'n-methylscopolamine': 30,
#  'nsc': 25,
#  'ntbc': 62,
#  'nafarelin': 125,
#  'novolog': 131,
#  'nuvaring': 128,
#  'nuvocid': 51,
#  'octreotide': 295,
#  'oestrogen': 141,
#  'optison': 145,
#  'org': 51,
#  'pci-32765': 76,
#  'pep005': 32,
#  'pge1': 192,
#  'pge2': 97,
#  'paroven': 18,
#  'photofrin': 349,
#  'prednefrin': 20,
#  'promacta': 48,
#  'protirelin': 31,
#  'prussian': 1,
#  'refludan': 104,
#  'revasc': 63,
#  'romidepsin': 82,
#  's-benzoylmercaptoacetyltriglycine': 12,
#  'som230': 65,
#  'su5416': 174,
#  'sativex': 85,
#  'saxagliptin': 58,
#  'signifor': 52,
#  'sonovue': 43,
#  'stalevo': 144,
#  'supremon': 204,
#  'symlin': 20,
#  't-a2-3': 40,
#  'tmc207': 35,
#  'tmc435': 24,
#  'tpgs': 16,
#  'tr-700': 44,
#  'tadenan': 7,
#  'terlipressin': 48,
#  'timentin': 27,
#  'tlcl': 18,
#  'triphasil': 40,
#  'triptorelin': 196,
#  'trisequens': 99,
#  'udca': 232,
#  'vacv': 132,
#  'vallergan': 52,
#  'vancocine': 92,
#  'vitrum': 51,
#  'westcort': 32,
#  'zncl2': 3,
#  'zyprexa': 126,
#  'abacavir': 132,
#  'abacavir-lamivudine': 73,
#  'abiraterone': 71,
#  'acamprosate': 229,
#  'acarbose': 44,
#  'acebutolol': 130,
#  'acenocoumarol': 28,
#  'acetaminophen': 187,
#  'acetate': 5,
#  'acetazolamide': 74,
#  'acetohydroxamic': 37,
#  'acetylcholine': 9,
#  'acipimox': 30,
#  'acitretin': 284,
#  'aclidinium': 29,
#  'actinomycin': 76,
#  'acyclovir': 178,
#  'adapalene': 59,
#  'adefovir': 104,
#  'adenosine': 111,
#  'afatinib': 83,
#  'agomelatine': 61,
#  'albendazole': 34,
#  'alcaftadine': 9,
#  'alclometasone': 16,
#  'alendronate': 94,
#  'alfentanil': 80,
#  'alfuzosin': 111,
#  'aliskiren': 102,
#  'allopurinol': 256,
#  'almotriptan': 138,
#  'alogliptin': 17,
#  'alosetron': 127,
#  'alpha-methyl-p-tyrosine': 43,
#  'alprazolam': 223,
#  'alvimopan': 13,
#  'amantadine': 133,
#  'ambrisentan': 104,
#  'amcinonide': 26,
#  'amifostine': 60,
#  'amikacin': 31,
#  'amiloride': 89,
#  'aminoglutethimide': 35,
#  'aminophylline': 66,
#  'amiodarone': 250,
#  'amisulpride': 89,
#  'amitriptyline': 134,
#  'amlexanox': 13,
#  'amlodipine': 307,
#  'ammonia': 7,
#  'ammonium': 6,
#  'amobarbital': 41,
#  'amorolfine': 8,
#  'amoxapine': 113,
#  'amoxicillin': 93,
#  'amphetamine': 146,
#  'amphotericin': 348,
#  'ampicillin': 30,
#  'amprenavir': 75,
#  'amsacrine': 109,
#  'anagrelide': 181,
#  'anastrozole': 172,
#  'anthracycline': 177,
#  'apixaban': 102,
#  'apomorphine': 55,
#  'apraclonidine': 112,
#  'apremilast': 25,
#  'aprepitant': 240,
#  'argatroban': 76,
#  'argenine': 23,
#  'arginine': 36,
#  'aripiprazole': 829,
#  'arsenic': 355,
#  'articaine': 81,
#  'ascorbate': 5,
#  'asenapine': 125,
#  'aspirin': 86,
#  'atazanavir': 237,
#  'atenolol': 135,
#  'atomoxetine': 171,
#  'atorvastatin': 230,
#  'atosiban': 32,
#  'atovaquone': 72,
#  'atracurium': 37,
#  'atropine': 208,
#  'auranofin': 50,
#  'avanafil': 113,
#  'axitinib': 121,
#  'azathioprine': 105,
#  'azelaic': 28,
#  'azelastine': 125,
#  'azilsartan': 45,
#  'azithromycin': 202,
#  'aztreonam': 94,
#  'baclofen': 236,
#  'balsalazide': 94,
#  'barium': 22,
#  'bazedoxifene': 42,
#  'beclomethasone': 115,
#  'belinostat': 40,
#  'benazepril': 103,
#  'benazeprilat': 75,
#  'bendamustine': 121,
#  'bendrofluazide': 35,
#  'benzathine': 111,
#  'benzocaine': 17,
#  'benzonatate': 26,
#  'benzoyl': 20,
#  'benzphetamine': 23}

# %%
df['NoSideEffects'] = df_symp['drugname'].str.lower().map(drugsymp)

# %%
df
# Out:
#        DRUG_NAME  DRUG_ID                                             SMILES  \
# 0    cyclosporin  DB00091  CC[C@@H]1NC(=O)[C@H]([C@H](O)[C@H](C)C\C=C\C)N...
# 1    fluvoxamine  DB00176             COCCCC\C(=N/OCCN)C1=CC=C(C=C1)C(F)(F)F
# 2     Masoprocol  DB00179  C[C@@H](CC1=CC(O)=C(O)C=C1)[C@H](C)CC1=CC(O)=C...
# 3     Bortezomib  DB00188  CC(C)C[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)C1=...
# 4       Tramadol  DB00193          COC1=CC=CC(=C1)[C@@]1(O)CCCC[C@@H]1CN(C)C
# ..           ...      ...                                                ...
# 256    Remdesvir  DB14761  CCC(CC)COC(=O)[C@H](C)N[P@](=O)(OC[C@H]1O[C@](...
# 257    EIDD-1931  DB15660   OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=CC(NO)=NC1=O
# 258    EIDD-2801  DB15661  CC(C)C(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=...
# 259    Baloxavir  DB15675  [H][C@@]12COCCN1C(=O)C1=C(O)C(=O)C=CN1N2[C@@H]...
# 260    zotatifin  DB16408  COC1=NC(OC)=C2C(O[C@]3([C@@H]([C@@H](CN(C)C)[C...
#
#      NoSideEffects
# 0            106.0
# 1             48.0
# 2              7.0
# 3              9.0
# 4             53.0
# ..             ...
# 256          111.0
# 257           17.0
# 258           26.0
# 259           20.0
# 260           23.0
#
# [261 rows x 4 columns]

# %%
drugsympall={}
for i in range(length):
    key=drugname[i].lower()
    value=side_eff[i]
    drugsympall[key]=value

# %%
df['AllSideEffects'] = df_symp['drugname'].str.lower().map(drugsympall)

# %%
df
# Out:
#        DRUG_NAME  DRUG_ID                                             SMILES  \
# 0    cyclosporin  DB00091  CC[C@@H]1NC(=O)[C@H]([C@H](O)[C@H](C)C\C=C\C)N...
# 1    fluvoxamine  DB00176             COCCCC\C(=N/OCCN)C1=CC=C(C=C1)C(F)(F)F
# 2     Masoprocol  DB00179  C[C@@H](CC1=CC(O)=C(O)C=C1)[C@H](C)CC1=CC(O)=C...
# 3     Bortezomib  DB00188  CC(C)C[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)C1=...
# 4       Tramadol  DB00193          COC1=CC=CC(=C1)[C@@]1(O)CCCC[C@@H]1CN(C)C
# ..           ...      ...                                                ...
# 256    Remdesvir  DB14761  CCC(CC)COC(=O)[C@H](C)N[P@](=O)(OC[C@H]1O[C@](...
# 257    EIDD-1931  DB15660   OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=CC(NO)=NC1=O
# 258    EIDD-2801  DB15661  CC(C)C(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=...
# 259    Baloxavir  DB15675  [H][C@@]12COCCN1C(=O)C1=C(O)C(=O)C=CN1N2[C@@H]...
# 260    zotatifin  DB16408  COC1=NC(OC)=C2C(O[C@]3([C@@H]([C@@H](CN(C)C)[C...
#
#      NoSideEffects                                     AllSideEffects
# 0            106.0  ['Abdominal cramps', 'Abdominal pain', 'Abdomi...
# 1             48.0  ['Abortion spontaneous', 'Asthenia', 'Body tem...
# 2              7.0  ['Dermatitis', 'Hyperglycaemia', 'Hypersensiti...
# 3              9.0  ['Blood pressure increased', 'Chest discomfort...
# 4             53.0  ['Acute coronary syndrome', 'Anaemia', 'Arthra...
# ..             ...                                                ...
# 256          111.0  ['Abscess', 'Acute interstitial nephritis', 'A...
# 257           17.0  ['Burning mouth', 'Cyanosis', 'Dermatitis', 'D...
# 258           26.0  ['Abdominal discomfort', 'Agitation', 'Broncho...
# 259           20.0  ['Allergic contact dermatitis', 'Anaphylactic ...
# 260           23.0  ['Agitation', 'Allergic urticaria', 'Anorexia'...
#
# [261 rows x 5 columns]

# %%
df.to_csv('NEW_Table_5A_261_Sider_drugmaped.csv', index=False)

# %%
#df['AllSideEffects'].count()

# %%
#filter1 = df['NoSideEffects']!='NaN'
#df.where(filter1)

# %%
df #[(df['NoSideEffects']!='NaN')]
#df[(df['Train'] != 'DeutscheBahn')
# Out:
#        DRUG_NAME  DRUG_ID                                             SMILES  \
# 0    cyclosporin  DB00091  CC[C@@H]1NC(=O)[C@H]([C@H](O)[C@H](C)C\C=C\C)N...
# 1    fluvoxamine  DB00176             COCCCC\C(=N/OCCN)C1=CC=C(C=C1)C(F)(F)F
# 2     Masoprocol  DB00179  C[C@@H](CC1=CC(O)=C(O)C=C1)[C@H](C)CC1=CC(O)=C...
# 3     Bortezomib  DB00188  CC(C)C[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)C1=...
# 4       Tramadol  DB00193          COC1=CC=CC(=C1)[C@@]1(O)CCCC[C@@H]1CN(C)C
# ..           ...      ...                                                ...
# 256    Remdesvir  DB14761  CCC(CC)COC(=O)[C@H](C)N[P@](=O)(OC[C@H]1O[C@](...
# 257    EIDD-1931  DB15660   OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=CC(NO)=NC1=O
# 258    EIDD-2801  DB15661  CC(C)C(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=...
# 259    Baloxavir  DB15675  [H][C@@]12COCCN1C(=O)C1=C(O)C(=O)C=CN1N2[C@@H]...
# 260    zotatifin  DB16408  COC1=NC(OC)=C2C(O[C@]3([C@@H]([C@@H](CN(C)C)[C...
#
#      NoSideEffects AllSideEffects
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
# ..             ...            ...
# 256            NaN            NaN
# 257            NaN            NaN
# 258            NaN            NaN
# 259            NaN            NaN
# 260            NaN            NaN
#
# [261 rows x 5 columns]

# %%
#contain_values = df[df['DRUG_NAME'].str.contains('Raloxifene')]
#contain_values #['AllSideEffects']

# %%
#df_sider=pd.read_csv("Table_8A_Sider_DrugwithTarget_5nearDrugs_Scored.tsv")
df_sider=pd.read_csv(neardrugtargetlist)

# %%
df_sider
# Out:
#          CID_mainD         drugname  \
# 0     CID100003916  levomepromazine
# 1     CID100003308         etodolac
# 2     CID100060668        etoposide
# 3     CID100003331        felbamate
# 4     CID100003342       fenoprofen
# ...            ...              ...
# 4016  CID100003386       fluoxetine
# 4017  CID100003386       fluoxetine
# 4018  CID100002215      apomorphine
# 4019  CID100003387  fluoxymesterone
# 4020  CID100001971         abacavir
#
#                                       Drug1_Target_Name     CID_likeD  \
# 0                            Dopamine D2 receptor (D2R)  CID100003559
# 1                  Prostaglandin G/H synthase 2 (COX-2)  CID100001301
# 2                           DNA topoisomerase II (TOP2)  CID100001690
# 3                 N-methyl-D-aspartate receptor (NMDAR)  CID100004054
# 4                      Prostaglandin G/H synthase (COX)  CID100003032
# ...                                                 ...           ...
# 4016                       Serotonin transporter (SERT)  CID100125889
# 4017                       Serotonin transporter (SERT)  CID100060795
# 4018                         Dopamine D2 receptor (D2R)  CID100004885
# 4019                             Androgen receptor (AR)  CID100005073
# 4020  Human immunodeficiency virus Reverse transcrip...  CID100060787
#
#          NearDrugs                                  Drug2_Target_Name  \
# 0      haloperidol                         Dopamine D2 receptor (D2R)
# 1         naproxen               Prostaglandin G/H synthase 2 (COX-2)
# 2      doxorubicin                        DNA topoisomerase II (TOP2)
# 3        memantine              N-methyl-D-aspartate receptor (NMDAR)
# 4       diclofenac                   Prostaglandin G/H synthase (COX)
# ...            ...                                                ...
# 4016    pregabalin  Voltage-gated calcium channel alpha-2/delta-1 ...
# 4017  aripiprazole                         Dopamine D2 receptor (D2R)
# 4018   pramipexole                         Dopamine D3 receptor (D3R)
# 4019   risperidone                         Dopamine D2 receptor (D2R)
# 4020    saquinavir     Human immunodeficiency virus Protease (HIV PR)
#
#       Matching_Score
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 4016               0
# 4017               0
# 4018               0
# 4019               0
# 4020               0
#
# [4021 rows x 7 columns]

# %%
df_sider.rename(columns = {'drugname':'DRUG_NAME'}, inplace = True)
df_sider
# Out:
#          CID_mainD        DRUG_NAME  \
# 0     CID100003916  levomepromazine
# 1     CID100003308         etodolac
# 2     CID100060668        etoposide
# 3     CID100003331        felbamate
# 4     CID100003342       fenoprofen
# ...            ...              ...
# 4016  CID100003386       fluoxetine
# 4017  CID100003386       fluoxetine
# 4018  CID100002215      apomorphine
# 4019  CID100003387  fluoxymesterone
# 4020  CID100001971         abacavir
#
#                                       Drug1_Target_Name     CID_likeD  \
# 0                            Dopamine D2 receptor (D2R)  CID100003559
# 1                  Prostaglandin G/H synthase 2 (COX-2)  CID100001301
# 2                           DNA topoisomerase II (TOP2)  CID100001690
# 3                 N-methyl-D-aspartate receptor (NMDAR)  CID100004054
# 4                      Prostaglandin G/H synthase (COX)  CID100003032
# ...                                                 ...           ...
# 4016                       Serotonin transporter (SERT)  CID100125889
# 4017                       Serotonin transporter (SERT)  CID100060795
# 4018                         Dopamine D2 receptor (D2R)  CID100004885
# 4019                             Androgen receptor (AR)  CID100005073
# 4020  Human immunodeficiency virus Reverse transcrip...  CID100060787
#
#          NearDrugs                                  Drug2_Target_Name  \
# 0      haloperidol                         Dopamine D2 receptor (D2R)
# 1         naproxen               Prostaglandin G/H synthase 2 (COX-2)
# 2      doxorubicin                        DNA topoisomerase II (TOP2)
# 3        memantine              N-methyl-D-aspartate receptor (NMDAR)
# 4       diclofenac                   Prostaglandin G/H synthase (COX)
# ...            ...                                                ...
# 4016    pregabalin  Voltage-gated calcium channel alpha-2/delta-1 ...
# 4017  aripiprazole                         Dopamine D2 receptor (D2R)
# 4018   pramipexole                         Dopamine D3 receptor (D3R)
# 4019   risperidone                         Dopamine D2 receptor (D2R)
# 4020    saquinavir     Human immunodeficiency virus Protease (HIV PR)
#
#       Matching_Score
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 4016               0
# 4017               0
# 4018               0
# 4019               0
# 4020               0
#
# [4021 rows x 7 columns]

# %%
df["DRUG_NAME"]=df["DRUG_NAME"].str.lower()

# %%
df.dropna(subset = ["NoSideEffects"], inplace=True)

# %%
def mapping(df,dfkey,dfvalue):
    key=dfkey
    value=dfvalue
    dictionary={}

    for i in range(len(df)):
        dictionary[key[i]]=value[i]
        
    return dictionary

# %%
df=df.reset_index()

# %%
s2=mapping(df,df['DRUG_NAME'].str.lower(),df['DRUG_ID'])

# %%
df_sider
# Out:
#          CID_mainD        DRUG_NAME  \
# 0     CID100003916  levomepromazine
# 1     CID100003308         etodolac
# 2     CID100060668        etoposide
# 3     CID100003331        felbamate
# 4     CID100003342       fenoprofen
# ...            ...              ...
# 4016  CID100003386       fluoxetine
# 4017  CID100003386       fluoxetine
# 4018  CID100002215      apomorphine
# 4019  CID100003387  fluoxymesterone
# 4020  CID100001971         abacavir
#
#                                       Drug1_Target_Name     CID_likeD  \
# 0                            Dopamine D2 receptor (D2R)  CID100003559
# 1                  Prostaglandin G/H synthase 2 (COX-2)  CID100001301
# 2                           DNA topoisomerase II (TOP2)  CID100001690
# 3                 N-methyl-D-aspartate receptor (NMDAR)  CID100004054
# 4                      Prostaglandin G/H synthase (COX)  CID100003032
# ...                                                 ...           ...
# 4016                       Serotonin transporter (SERT)  CID100125889
# 4017                       Serotonin transporter (SERT)  CID100060795
# 4018                         Dopamine D2 receptor (D2R)  CID100004885
# 4019                             Androgen receptor (AR)  CID100005073
# 4020  Human immunodeficiency virus Reverse transcrip...  CID100060787
#
#          NearDrugs                                  Drug2_Target_Name  \
# 0      haloperidol                         Dopamine D2 receptor (D2R)
# 1         naproxen               Prostaglandin G/H synthase 2 (COX-2)
# 2      doxorubicin                        DNA topoisomerase II (TOP2)
# 3        memantine              N-methyl-D-aspartate receptor (NMDAR)
# 4       diclofenac                   Prostaglandin G/H synthase (COX)
# ...            ...                                                ...
# 4016    pregabalin  Voltage-gated calcium channel alpha-2/delta-1 ...
# 4017  aripiprazole                         Dopamine D2 receptor (D2R)
# 4018   pramipexole                         Dopamine D3 receptor (D3R)
# 4019   risperidone                         Dopamine D2 receptor (D2R)
# 4020    saquinavir     Human immunodeficiency virus Protease (HIV PR)
#
#       Matching_Score
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 4016               0
# 4017               0
# 4018               0
# 4019               0
# 4020               0
#
# [4021 rows x 7 columns]

# %%
df_sider['DB_DRUG_ID'] = df_sider['DRUG_NAME'].str.lower().map(s2)

# %%
df_sider.dropna(subset = ["DB_DRUG_ID"], inplace=True)

# %%
df_sider.to_csv('NEW_Table_11A_300Drug_NearDrug_Target.csv', index = False)
